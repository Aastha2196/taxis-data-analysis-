# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\ASUS\Downloads\nyc_taxis.csv')
data
# Out:
#        pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0             2016             1           1                 5            0
# 1             2016             1           1                 5            0
# 2             2016             1           1                 5            0
# 3             2016             1           1                 5            0
# 4             2016             1           1                 5            0
# ...            ...           ...         ...               ...          ...
# 89555         2016             6          30                 4            5
# 89556         2016             6          30                 4            5
# 89557         2016             6          30                 4            5
# 89558         2016             6          30                 4            5
# 89559         2016             6          30                 4            5
#
# ...

# %%
##Top 10 rows of data

data.head(10)
# Out:
#    pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0         2016             1           1                 5            0
# 1         2016             1           1                 5            0
# 2         2016             1           1                 5            0
# 3         2016             1           1                 5            0
# 4         2016             1           1                 5            0
# 5         2016             1           1                 5            0
# 6         2016             1           1                 5            0
# 7         2016             1           1                 5            0
# 8         2016             1           1                 5            0
# 9         2016             1           1                 5            0
#
#    pickup_location_code  dropoff_location_code  trip_distance  trip_length  \
# 0                     2                      4          21.00         2037
# ...

# %%
##Last 10 rows of data

data.tail(10)
# Out:
#        pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 89550         2016             6          30                 4            5
# 89551         2016             6          30                 4            5
# 89552         2016             6          30                 4            5
# 89553         2016             6          30                 4            5
# 89554         2016             6          30                 4            5
# 89555         2016             6          30                 4            5
# 89556         2016             6          30                 4            5
# 89557         2016             6          30                 4            5
# 89558         2016             6          30                 4            5
# 89559         2016             6          30                 4            5
#
#        pickup_location_code  dropoff_location_code  trip_distance  \
# ...

# %%
##statistical description

data.describe().T
# Out:
#                          count         mean          std      min      25%  \
# pickup_year            89560.0  2016.000000     0.000000  2016.00  2016.00
# pickup_month           89560.0     3.614471     1.692354     1.00     2.00
# pickup_day             89560.0    15.693535     8.694046     1.00     8.00
# pickup_dayofweek       89560.0     3.841335     2.001929     1.00     2.00
# pickup_time            89560.0     3.082671     1.404460     0.00     2.00
# pickup_location_code   89560.0     2.959882     0.823339     0.00     2.00
# dropoff_location_code  89560.0     3.379243     1.382522     0.00     2.00
# trip_distance          89560.0    12.667426     5.167848     0.00     9.26
# trip_length            89560.0  2235.981108  3238.775577     1.00  1394.00
# fare_amount            89560.0    38.404484    12.891446   -52.00    29.50
# fees_amount            89560.0     1.209176     0.945975    -1.80     0.80
# ...

# %%
Area of concern here gets generated by the negative fare amount , so this needs to be looked.

# %%
##unique values in fare amount column

data['fare_amount'].nunique()
# Out:
# 257

# %%
##avg price of fare amount

data['fare_amount'].mean()
# Out:
# 38.404484033050466

# %%
##show null values in data frame

data.isnull().sum()
# Out:
# pickup_year              0
# pickup_month             0
# pickup_day               0
# pickup_dayofweek         0
# pickup_time              0
# pickup_location_code     0
# dropoff_location_code    0
# trip_distance            0
# trip_length              0
# fare_amount              0
# fees_amount              0
# tolls_amount             0
# tip_amount               0
# total_amount             0
# payment_type             0
# dtype: int64

# %%
 no null values

# %%
##check for the datatypes of the coulumns

data.dtypes
# Out:
# pickup_year                int64
# pickup_month               int64
# pickup_day                 int64
# pickup_dayofweek           int64
# pickup_time                int64
# pickup_location_code       int64
# dropoff_location_code      int64
# trip_distance            float64
# trip_length                int64
# fare_amount              float64
# fees_amount              float64
# tolls_amount             float64
# tip_amount               float64
# total_amount             float64
# payment_type               int64
# dtype: object

# %%
no object type value
